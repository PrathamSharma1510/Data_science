# %%
import pandas as pd

# %%
# Q1

# %%
# Q2
df = pd.DataFrame({
    'A': [1, 2, 3],
    'B': [4, 5, 6],
    'C': [7, 8, 9]
})
print("Original DataFrame:")
print(df)

list_newindex=[]
for i in range(1,len(df)):
    list_newindex.append(i)

df.insert=list_newindex
print("\nReindexed DataFrame:")
print(df_reindexed)
# Out:
# Original DataFrame:
#    A  B  C
# 0  1  4  7
# 1  2  5  8
# 2  3  6  9
#
# Reindexed DataFrame:
#    A  B  C
# 1  1  4  7
# 3  2  5  8
# 5  3  6  9

# %%
# Q3)
df = pd.DataFrame({
    'A': [1, 2, 3],
    'values': [4, 5, 6],
    'Text': ['Hello','OK','cool']
})
sum(df['values'][0:2])
# Out:
# 9

# %%
# Q4
df['Word_Count']=df['Text'].str.len()
df
# Out:
#    A  values   Text  Word_Count
# 0  1       4  Hello           5
# 1  2       5     OK           2
# 2  3       6   cool           4

# %%
# Q5
df=pd.read_excel('Book1.xlsx')
df
# Out:
#    A  values  Text Word_Count  Unnamed: 4
# 0  0       1     4      Hello           5
# 1  1       2     5         OK           2
# 2  2       3     6       cool           4

# %%
# Q6
# !pip install faker
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 321.3 kB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 247.7/247.7 kB 211.8 kB/s eta 0:00:0000:0100:01
# ...
#
# [notice] A new release of pip is available: 23.0 -> 23.3.1
# [notice] To update, run: /Applications/Xcode.app/Contents/Developer/usr/bin/python3 -m pip install --upgrade pip

# %%
from faker import Faker

fake = Faker()

data = {
    'Name': [fake.name() for _ in range(50)],
    'Email': [fake.email() for _ in range(50)],
    'Phone': [fake.phone_number() for _ in range(50)]
}

df = pd.DataFrame(data)

print(df)
# Out:
#                       Name                             Email  \
# 0     William Williams Jr.               joneill@example.org
# 1          Emily Stevenson         abbottcynthia@example.net
# 2          Robert Robinson            davidreyes@example.org
# 3          Matthew Lambert                vyoung@example.com
# 4              Kevin Allen                 rpham@example.com
# 5         Michael Cantrell             ugonzales@example.com
# 6        Brittany Hatfield                asmith@example.org
# 7              Kim Morales                adam07@example.net
# 8            Pamela Miller               mgraham@example.net
# 9            Phillip Riley                kara49@example.com
# 10            Rachel Downs         rhodeskristin@example.net
# 11           Kristin Ortiz               tanya42@example.net
# 12           Nicole Wright              cheryl84@example.com
# 13            Stacey Vance              nicole43@example.org
# ...

# %%
df['Username']=df['Email'].str.split('@').str[0]
df
# Out:
#                       Name                             Email  \
# 0     William Williams Jr.               joneill@example.org
# 1          Emily Stevenson         abbottcynthia@example.net
# 2          Robert Robinson            davidreyes@example.org
# 3          Matthew Lambert                vyoung@example.com
# 4              Kevin Allen                 rpham@example.com
# 5         Michael Cantrell             ugonzales@example.com
# 6        Brittany Hatfield                asmith@example.org
# 7              Kim Morales                adam07@example.net
# 8            Pamela Miller               mgraham@example.net
# 9            Phillip Riley                kara49@example.com
# 10            Rachel Downs         rhodeskristin@example.net
# 11           Kristin Ortiz               tanya42@example.net
# 12           Nicole Wright              cheryl84@example.com
# 13            Stacey Vance              nicole43@example.org
# ...

# %%
# Q8
data = {'A': [3, 8, 6, 2, 9,8,9],
        'B': [5, 2, 9, 3, 1,2,1],
        'C': [1, 7, 4, 5, 2,7,2]}
df = pd.DataFrame(data)
ans=df[(df['A']>5) & (df['B']<10)]
ans
# Out:
#    A  B  C
# 1  8  2  7
# 2  6  9  4
# 4  9  1  2
# 5  8  2  7
# 6  9  1  2

# %%
# Q9
data = {'A': [3, 8, 6, 2, 9,8,9],
        'Values': [5, 2, 9, 3, 1,2,1],
        'C': [1, 7, 4, 5, 2,7,2]}
df = pd.DataFrame(data)
m=df['Values'].mean()
mead=df['Values'].median()
sd=df['Values'].std()

print(m," ",mead," ",sd)
# Out:
# 3.2857142857142856   2.0   2.870208222079931

# %%
# Q10
data = {
    'Date': ['2023-01-01', '2023-01-02', '2023-01-03', '2023-01-04', '2023-01-05', 
             '2023-01-06', '2023-01-07', '2023-01-08', '2023-01-09', '2023-01-10', 
             '2023-01-11', '2023-01-12', '2023-01-13', '2023-01-14', '2023-01-15', 
             '2023-01-16', '2023-01-17', '2023-01-18', '2023-01-19', '2023-01-20', 
             '2023-01-21', '2023-01-22', '2023-01-23', '2023-01-24', '2023-01-25', 
             '2023-01-26', '2023-01-27', '2023-01-28', '2023-01-29', '2023-01-30'],
    'Sales': [272, 147, 217, 292, 423, 356, 198, 234, 256, 312, 
              142, 150, 349, 371, 295, 333, 222, 198, 267, 345, 
              433, 256, 322, 147, 169, 213, 238, 359, 392, 276]
}

df = pd.DataFrame(data)

df['MovingAverage']=df['Sales'].rolling(7).mean()
df
# Out:
#           Date  Sales  MovingAverage
# 0   2023-01-01    272            NaN
# 1   2023-01-02    147            NaN
# 2   2023-01-03    217            NaN
# 3   2023-01-04    292            NaN
# 4   2023-01-05    423            NaN
# 5   2023-01-06    356            NaN
# 6   2023-01-07    198     272.142857
# 7   2023-01-08    234     266.714286
# 8   2023-01-09    256     282.285714
# 9   2023-01-10    312     295.857143
# 10  2023-01-11    142     274.428571
# 11  2023-01-12    150     235.428571
# 12  2023-01-13    349     234.428571
# 13  2023-01-14    371     259.142857
# 14  2023-01-15    295     267.857143
# 15  2023-01-16    333     278.857143
# 16  2023-01-17    222     266.000000
# 17  2023-01-18    198     274.000000
# 18  2023-01-19    267     290.714286
# 19  2023-01-20    345     290.142857
# 20  2023-01-21    433     299.000000
# 21  2023-01-22    256     293.428571
# 22  2023-01-23    322     291.857143
# 23  2023-01-24    147     281.142857
# ...

# %%
df['Date'] = pd.to_datetime(df['Date'])

df['Weekday'] = df['Date'].dt.day_name()
df
# Out:
#          Date  Sales  MovingAverage    Weekday
# 0  2023-01-01    272            NaN     Sunday
# 1  2023-01-02    147            NaN     Monday
# 2  2023-01-03    217            NaN    Tuesday
# 3  2023-01-04    292            NaN  Wednesday
# 4  2023-01-05    423            NaN   Thursday
# 5  2023-01-06    356            NaN     Friday
# 6  2023-01-07    198     272.142857   Saturday
# 7  2023-01-08    234     266.714286     Sunday
# 8  2023-01-09    256     282.285714     Monday
# 9  2023-01-10    312     295.857143    Tuesday
# 10 2023-01-11    142     274.428571  Wednesday
# 11 2023-01-12    150     235.428571   Thursday
# 12 2023-01-13    349     234.428571     Friday
# 13 2023-01-14    371     259.142857   Saturday
# 14 2023-01-15    295     267.857143     Sunday
# 15 2023-01-16    333     278.857143     Monday
# 16 2023-01-17    222     266.000000    Tuesday
# 17 2023-01-18    198     274.000000  Wednesday
# 18 2023-01-19    267     290.714286   Thursday
# ...

# %%
# Q12
df[(df['Date']>'2023-01-01') & (df['Date']<'2023-01-31')]
# Out:
#          Date  Sales  MovingAverage    Weekday
# 1  2023-01-02    147            NaN     Monday
# 2  2023-01-03    217            NaN    Tuesday
# 3  2023-01-04    292            NaN  Wednesday
# 4  2023-01-05    423            NaN   Thursday
# 5  2023-01-06    356            NaN     Friday
# 6  2023-01-07    198     272.142857   Saturday
# 7  2023-01-08    234     266.714286     Sunday
# 8  2023-01-09    256     282.285714     Monday
# 9  2023-01-10    312     295.857143    Tuesday
# 10 2023-01-11    142     274.428571  Wednesday
# 11 2023-01-12    150     235.428571   Thursday
# 12 2023-01-13    349     234.428571     Friday
# 13 2023-01-14    371     259.142857   Saturday
# 14 2023-01-15    295     267.857143     Sunday
# 15 2023-01-16    333     278.857143     Monday
# 16 2023-01-17    222     266.000000    Tuesday
# 17 2023-01-18    198     274.000000  Wednesday
# 18 2023-01-19    267     290.714286   Thursday
# 19 2023-01-20    345     290.142857     Friday
# ...
